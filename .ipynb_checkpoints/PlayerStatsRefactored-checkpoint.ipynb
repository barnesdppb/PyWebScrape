# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs
import datetime
import random
import re
import pprint
import json
import pandas as pd

def getMatchLinks (articleUrl):
    html = urlopen("http://www.espn.co.uk/rugby/fixtures/_/date/" + articleUrl)
    bsObj = bs(html, "lxml")
    tst = bsObj.find("section", {"id":"pane-main"}).findAll("script", {"type":"text/javascript"})
    for t in tst:
        json_text = re.search(r'^\s*window\.__INITIAL_STATE__\s*=\s*({.*?})\s*;\s*$',
                      t.string, flags=re.DOTALL | re.MULTILINE).group(1)

    json_out = json.loads(json_text)
    
    # Get just the match links
    json_match = json_out['schedule']['groups']
    matches = []
    for m in json_match:
        for c in m['complete']:
            matches.append(c['result']['href'])
            
    return matches

links = getMatchLinks('20160917')
links
# Out:
# ['/rugby/report?gameId=289315&league=244293',
#  '/rugby/report?gameId=268579&league=244293',
#  '/rugby/report?gameId=290006&league=267979',
#  '/rugby/report?gameId=290007&league=267979',
#  '/rugby/report?gameId=290008&league=267979',
#  '/rugby/match?gameId=290268&league=270559',
#  '/rugby/match?gameId=290265&league=270559',
#  '/rugby/match?gameId=290266&league=270559',
#  '/rugby/match?gameId=290270&league=270559',
#  '/rugby/match?gameId=290269&league=270559',
#  '/rugby/report?gameId=290441&league=270557',
#  '/rugby/report?gameId=290440&league=270557',
#  '/rugby/match?gameId=290152&league=270555',
#  '/rugby/match?gameId=290149&league=270555',
#  '/rugby/match?gameId=289875&league=289232',
#  '/rugby/match?gameId=290197&league=270563',
#  '/rugby/match?gameId=290196&league=270563']

# %%
def getStatsLinks (articleUrl):
    html = urlopen("http://www.espn.co.uk" + articleUrl)
    bsObj = bs(html, "lxml")
    tst = bsObj.find("section", {"id":"pane-main"}).findAll("script", {"type":"text/javascript"})
    
    json_out = []
    for t in tst:
        json_text = re.search(r'^\s*window\.__INITIAL_STATE__\s*=\s*({.*?})\s*;\s*$',
                          t.string, flags=re.DOTALL | re.MULTILINE).group(1)
        json_out.append(json.loads(json_text))

    for j in json_out[0]['gamePackage']['links']:
        if j['pageType'] == 'matchstats':
            match_s = j['href']
        elif j['pageType'] == 'playerstats':
            player_s = j['href']
          
    try: 
        match_s, player_s
    except NameError:
        match_s, player_s = None, None

    return match_s, player_s

m, p = getStatsLinks(links[5])
print(m)
print(p)
# Out:
# /rugby/matchstats?gameId=290268&league=270559
# /rugby/playerstats?gameId=290268&league=270559

# %%
def getStats(statsUrl):
    html = urlopen("http://www.espn.co.uk" + statsUrl)
    bsObj = bs(html, "lxml")  
    tst = bsObj.find("section", {"id":"pane-main"}).findAll("script", {"type":"text/javascript"})
    
    stat_out = []
    for t in tst:
        json_text = re.search(r'^\s*window\.__INITIAL_STATE__\s*=\s*({.*?})\s*;\s*$',
                              t.string, flags=re.DOTALL | re.MULTILINE).group(1)
        stat_out.append(json.loads(json_text))
        
    return stat_out[0]

# %%
getStats(p)
# Out:
# {'clubhouse': {},
#  'gamePackage': {'HeadToHeadNode': [{'events': [{'atVs': '@',
#       'awayTeamId': '25917',
#       'awayTeamScore': '24',
#       'gameDate': '2016-03-27T14:15Z',
#       'gameResult': 'W',
#       'homeTeamId': '143737',
#       'homeTeamScore': '19',
#       'id': '268851',
#       'leagueAbbreviation': 'Top 14 Orange',
#       'leagueName': 'Top 14 Orange',
#       'links': [{'href': 'http://www.espn.co.uk/rugby/match?gameId=268851&league=270559',
#         'text': 'Summary'},
#        {'href': 'http://www.espn.co.uk/rugby/match?gameId=268851&league=270559',
#         'text': 'Match'},
#        {'href': 'http://www.espn.co.uk/rugby/matchstats?gameId=268851&league=270559',
#         'text': 'Match Stats'}],
#       'opponent': {'abbreviation': 'BEG',
#        'displayName': 'Bordeaux Begles',
#        'id': '143737',
#        'links': [{'href': 'http://www.espn.co.uk/rugby/team/_/id/143737/bordeaux-begles',
#          'text': 'Clubhouse'}],
#        'logo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#        'uid': 's:300~t:143737'},
#       'opponentLogo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#       'score': '24-19 '},
#      {'atVs': 'vs',
#       'awayTeamId': '143737',
#       'awayTeamScore': '37',
#       'gameDate': '2016-01-24T15:15Z',
#       'gameResult': 'L',
#       'homeTeamId': '25917',
#       'homeTeamScore': '28',
#       'id': '271511',
#       'leagueAbbreviation': 'European Rugby Champions Cup',
#       'leagueName': 'European Rugby Champions Cup',
#       'links': [{'href': 'http://www.espn.co.uk/rugby/match?gameId=271511&league=271937',
#         'text': 'Summary'},
#        {'href': 'http://www.espn.co.uk/rugby/match?gameId=271511&league=271937',
#         'text': 'Match'},
#        {'href': 'http://www.espn.co.uk/rugby/matchstats?gameId=271511&league=271937',
#         'text': 'Match Stats'}],
#       'opponent': {'abbreviation': 'BEG',
#        'displayName': 'Bordeaux Begles',
#        'id': '143737',
#        'links': [{'href': 'http://www.espn.co.uk/rugby/team/_/id/143737/bordeaux-begles',
#          'text': 'Clubhouse'}],
#        'logo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#        'uid': 's:300~t:143737'},
#       'opponentLogo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#       'score': '37-28 '},
#      {'atVs': '@',
#       'awayTeamId': '25917',
#       'awayTeamScore': '28',
#       'gameDate': '2016-01-08T19:45Z',
#       'gameResult': 'W',
#       'homeTeamId': '143737',
#       'homeTeamScore': '10',
#       'id': '271421',
#       'leagueAbbreviation': 'European Rugby Champions Cup',
#       'leagueName': 'European Rugby Champions Cup',
#       'links': [{'href': 'http://www.espn.co.uk/rugby/match?gameId=271421&league=271937',
#         'text': 'Summary'},
#        {'href': 'http://www.espn.co.uk/rugby/match?gameId=271421&league=271937',
#         'text': 'Match'},
#        {'href': 'http://www.espn.co.uk/rugby/matchstats?gameId=271421&league=271937',
#         'text': 'Match Stats'}],
#       'opponent': {'abbreviation': 'BEG',
#        'displayName': 'Bordeaux Begles',
#        'id': '143737',
#        'links': [{'href': 'http://www.espn.co.uk/rugby/team/_/id/143737/bordeaux-begles',
#          'text': 'Clubhouse'}],
#        'logo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#        'uid': 's:300~t:143737'},
#       'opponentLogo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#       'score': '28-10 '},
#      {'atVs': 'vs',
#       'awayTeamId': '143737',
#       'awayTeamScore': '26',
#       'gameDate': '2015-09-12T16:30Z',
#       'gameResult': 'D',
#       'homeTeamId': '25917',
#       'homeTeamScore': '26',
#       'id': '268651',
#       'leagueAbbreviation': 'Top 14 Orange',
#       'leagueName': 'Top 14 Orange',
#       'links': [{'href': 'http://www.espn.co.uk/rugby/match?gameId=268651&league=270559',
#         'text': 'Summary'},
#        {'href': 'http://www.espn.co.uk/rugby/match?gameId=268651&league=270559',
#         'text': 'Match'},
#        {'href': 'http://www.espn.co.uk/rugby/matchstats?gameId=268651&league=270559',
#         'text': 'Match Stats'}],
#       'opponent': {'abbreviation': 'BEG',
#        'displayName': 'Bordeaux Begles',
#        'id': '143737',
#        'links': [{'href': 'http://www.espn.co.uk/rugby/team/_/id/143737/bordeaux-begles',
#          'text': 'Clubhouse'}],
#        'logo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#        'uid': 's:300~t:143737'},
#       'opponentLogo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#       'score': '26-26 '},
#      {'atVs': 'vs',
#       'awayTeamId': '143737',
#       'awayTeamScore': '23',
#       'gameDate': '2015-03-13T19:45Z',
#       'gameResult': 'W',
#       'homeTeamId': '25917',
#       'homeTeamScore': '31',
#       'id': '232593',
#       'leagueAbbreviation': 'Top 14 Orange',
#       'leagueName': 'Top 14 Orange',
#       'links': [{'href': 'http://www.espn.co.uk/rugby/match?gameId=232593&league=270559',
#         'text': 'Summary'},
#        {'href': 'http://www.espn.co.uk/rugby/match?gameId=232593&league=270559',
#         'text': 'Match'},
#        {'href': 'http://www.espn.co.uk/rugby/matchstats?gameId=232593&league=270559',
#         'text': 'Match Stats'}],
#       'opponent': {'abbreviation': 'BEG',
#        'displayName': 'Bordeaux Begles',
#        'id': '143737',
#        'links': [{'href': 'http://www.espn.co.uk/rugby/team/_/id/143737/bordeaux-begles',
#          'text': 'Clubhouse'}],
#        'logo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#        'uid': 's:300~t:143737'},
#       'opponentLogo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/143737.png',
#       'score': '31-23 '}],
#     'team': {'abbreviation': 'CLER',
#      'displayName': 'Clermont Auvergne',
#      'id': '25917',
#      'links': [{'href': 'http://www.espn.co.uk/rugby/team/_/id/25917/clermont-auvergne',
#        'text': 'Clubhouse'}],
#      'logo': 'http://a.espncdn.com/i/teamlogos/rugby/teams/500/25917.png',
#      'uid': 's:300~t:25917'}}],
#   'analytics': {'chartbeat': {'title': 'Clermont Auvergne vs Bordeaux Begles - Player Statistics - Top 14 Orange 2017 - 17 Sep, 2016 - ESPN'},
#    'omniture': {'contentType': 'game:playerstats',
#     'eVar44': 'gamepackage',
#     'gameInfo': '290268+Clermont Auvergne vs Bordeaux Begles',
#     'gameState': 'post',
#     'league': '270559',
#     'pageName': 'rugby:game:playerstats'}},
#   'article': {'date': '',
#    'description': '',
#    'headline': '',
#    'href': '',
#    'id': 0,
#    'images': [],
#    'source': '',
#    'type': 0,
#    'video': {}},
#   'commentaryFeedback': {},
#   'gameState': 'final',
#   'gameStateClass': 'post',
#   'gameStrip': {'date': '17/09',
#    'gameState': 'final',
#    'header': 'Top 14 Orange 2017',
#    'isTeamLinkActive': True,
#    'network': '',
#    'target': '',
#    'teams': {'away': {'abbrev': 'BEG',
#      'color': '000099',
#      'href': '/rugby/team/_/id/143737/bordeaux-begles',
#      'id': '143737',
#      'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=42&w=42',
#      'name': 'Bordeaux Begles',
#      'overDetails': '',
#      'record': '',
#      'runDetails': '16',
#      'score': '16',
#      'scoreMarkup': '16',
#      'scoreMarkupMobile': '16',
#      'trackingName': '&lpos=rugby:game:game:clubhouse:team',
#      'uid': 's:300~t:143737',
#      'winner': False},
#     'home': {'abbrev': 'CLER',
#      'color': 'FFCC00',
#      'href': '/rugby/team/_/id/25917/clermont-auvergne',
#      'id': '25917',
#      'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=42&w=42',
#      'name': 'Clermont Auvergne',
#      'overDetails': '',
#      'record': '',
#      'runDetails': '40',
#      'score': '40',
#      'scoreMarkup': '40',
#      'scoreMarkupMobile': '40',
#      'trackingName': '&lpos=rugby:game:game:clubhouse:team',
#      'uid': 's:300~t:25917',
#      'winner': True}},
#    'time': 'FT',
#    'winnerClass': 'team-a-winner',
#    'winnerClassMobile': 'cscore--home-winner'},
#   'headToHead': {'data': [{'away': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'date': '2016-03-27T14:15Z',
#      'home': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=268851&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=268851&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'W',
#      'resultValue': 'W',
#      'score': '19-24'},
#     {'away': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'date': '2016-01-24T15:15Z',
#      'home': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'league': 'European Rugby Champions Cup',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=271511&league=271937',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=271511&league=271937',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'L',
#      'resultValue': 'L',
#      'score': '28-37'},
#     {'away': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'date': '2016-01-08T19:45Z',
#      'home': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'league': 'European Rugby Champions Cup',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=271421&league=271937',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=271421&league=271937',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'W',
#      'resultValue': 'W',
#      'score': '10-28'},
#     {'away': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'date': '2015-09-12T16:30Z',
#      'home': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=268651&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=268651&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'D',
#      'resultValue': 'D',
#      'score': '26-26'},
#     {'away': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'date': '2015-03-13T19:45Z',
#      'home': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=232593&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=232593&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'W',
#      'resultValue': 'W',
#      'score': '31-23'}],
#    'team': {'abbreviation': 'CLER',
#     'link': {'classes': [],
#      'dataRoute': False,
#      'external': False,
#      'href': '/rugby/team/_/id/25917/clermont-auvergne',
#      'isRouterLink': True,
#      'text': '',
#      'to': '/rugby/team/_/id/25917/clermont-auvergne',
#      'trackingName': '&lpos=rugby:game:subnav:history'},
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#     'name': 'CLER'},
#    'text': {'col1': 'LAST FIVE GAMES',
#     'col2': 'DATE',
#     'col3': 'COMPETITION',
#     'title': 'Head To Head Record'}},
#   'leagueUid': 's:300~l:8005',
#   'links': [{'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/match?gameId=290268&league=270559',
#     'isRouterLink': True,
#     'pageType': 'match',
#     'text': 'Summary',
#     'to': '/rugby/match?gameId=290268&league=270559',
#     'trackingName': '&lpos=rugby:game:subnav:match'},
#    {'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/commentary?gameId=290268&league=270559',
#     'isRouterLink': True,
#     'pageType': 'commentary',
#     'text': 'Commentary',
#     'to': '/rugby/commentary?gameId=290268&league=270559',
#     'trackingName': '&lpos=rugby:game:subnav:commentary'},
#    {'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/matchstats?gameId=290268&league=270559',
#     'isRouterLink': True,
#     'pageType': 'matchstats',
#     'text': 'Match Stats',
#     'to': '/rugby/matchstats?gameId=290268&league=270559',
#     'trackingName': '&lpos=rugby:game:subnav:matchstats'},
#    {'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/playerstats?gameId=290268&league=270559',
#     'isRouterLink': True,
#     'pageType': 'playerstats',
#     'text': 'Player Stats',
#     'to': '/rugby/playerstats?gameId=290268&league=270559',
#     'trackingName': '&lpos=rugby:game:subnav:playerstats'},
#    {'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/lineups?gameId=290268&league=270559',
#     'isRouterLink': True,
#     'pageType': 'lineups',
#     'text': 'Lineups',
#     'to': '/rugby/lineups?gameId=290268&league=270559',
#     'trackingName': '&lpos=rugby:game:subnav:lineups'},
#    {'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/table/_/league/270559',
#     'isRouterLink': True,
#     'pageType': 'table',
#     'text': 'Table',
#     'to': '/rugby/table/_/league/270559',
#     'trackingName': '&lpos=rugby:game:subnav:table'},
#    {'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/conversation?gameId=290268&league=270559',
#     'isRouterLink': True,
#     'pageType': 'conversation',
#     'text': 'Conversation',
#     'to': '/rugby/conversation?gameId=290268&league=270559',
#     'trackingName': '&lpos=rugby:game:subnav:conversation'}],
#   'matchAttacking': {'away': {'color': '#000099',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#     'name': 'BEG'},
#    'col': [[{'data': {'awayText': '17%',
#        'awayValue': 17,
#        'homeText': '82%',
#        'homeValue': 82,
#        'text': 'Possession'},
#       'type': 'dataVis'},
#      {'data': {'awayText': '0%',
#        'awayValue': 0,
#        'homeText': '0%',
#        'homeValue': 0,
#        'text': 'Territory'},
#       'size': 'large',
#       'type': 'dataVis'}],
#     [{'data': [{'awayValue': '0% / 20%',
#         'homeValue': '100% / 80%',
#         'text': 'Possession 1H/2H'},
#        {'awayValue': '0% / 0%',
#         'homeValue': '0% / 0%',
#         'text': 'Territory 1H/2H'},
#        {'awayValue': '2', 'homeValue': '3', 'text': 'Clean Breaks'},
#        {'awayValue': '9', 'homeValue': '10', 'text': 'Defenders Beaten'},
#        {'awayValue': '8', 'homeValue': '12', 'text': 'Offload'},
#        {'awayValue': '61 / 64 (95%)',
#         'homeValue': '82 / 82 (100%)',
#         'text': 'Rucks Won'},
#        {'awayValue': '0 / 0 (0%)',
#         'homeValue': '0 / 0 (0%)',
#         'text': 'Mauls Won'},
#        {'awayValue': '12', 'homeValue': '11', 'text': 'Turnovers Conceded'}],
#       'type': 'table'}]],
#    'home': {'color': '#FFCC00',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#     'name': 'CLER'},
#    'split': False,
#    'title': 'Attacking'},
#   'matchAwayForm': {'data': [{'away': {'abbreviation': 'GRENO',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/167303/grenoble',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/167303/grenoble',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/default-team-logo-500.png&h=35&w=35',
#       'name': 'GRENO'},
#      'date': '2017-03-11T17:30Z',
#      'home': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=290370&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=290370&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'W',
#      'resultValue': 'W',
#      'score': '46-14'},
#     {'away': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'date': '2017-03-05T16:00Z',
#      'home': {'abbreviation': 'SFRAN',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25921/stade-francais-paris',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25921/stade-francais-paris',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25921.png&h=35&w=35',
#       'name': 'SFRAN'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=290368&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=290368&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'L',
#      'resultValue': 'L',
#      'score': '32-9'},
#     {'away': {'abbreviation': 'CAS',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25916/castres-olympique',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25916/castres-olympique',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25916.png&h=35&w=35',
#       'name': 'CAS'},
#      'date': '2017-02-19T11:30Z',
#      'home': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=290360&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=290360&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'L',
#      'resultValue': 'L',
#      'score': '17-29'},
#     {'away': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'date': '2017-01-29T15:45Z',
#      'home': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=290350&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=290350&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'D',
#      'resultValue': 'D',
#      'score': '23-23'},
#     {'away': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'date': '2017-01-21T13:00Z',
#      'home': {'abbreviation': 'ULST',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25926/ulster',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25926/ulster',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/default-team-logo-500.png&h=35&w=35',
#       'name': 'ULST'},
#      'league': 'European Rugby Champions Cup',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=290691&league=271937',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=290691&league=271937',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'W',
#      'resultValue': 'W',
#      'score': '22-26'}],
#    'team': {'abbreviation': 'BEG',
#     'link': {'classes': [],
#      'dataRoute': False,
#      'external': False,
#      'href': '/rugby/team/_/id/143737/bordeaux-begles',
#      'isRouterLink': True,
#      'text': '',
#      'to': '/rugby/team/_/id/143737/bordeaux-begles',
#      'trackingName': '&lpos=rugby:game:subnav:history'},
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#     'name': 'BEG'},
#    'text': {'col1': 'LAST FIVE GAMES',
#     'col2': 'DATE',
#     'col3': 'COMPETITION',
#     'title': 'Bordeaux Begles Form'}},
#   'matchCommentary': {'events': [{'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Player substituted - Jefferson Poirot , Bordeaux Begles',
#      'time': "61'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Substitute on - Sebastien Taofifenua , Bordeaux Begles',
#      'time': "61'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Substitute on - Cyril Cazeaux , Bordeaux Begles',
#      'time': "61'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Player substituted - Jandr̩ Marais , Bordeaux Begles',
#      'time': "61'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 40,
#      'text': 'End of second half',
#      'time': "81'",
#      'type': 12},
#     {'awayScore': 16,
#      'homeScore': 40,
#      'text': 'Substitute on - Ian Madigan , Bordeaux Begles',
#      'time': "78'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 40,
#      'text': 'Player substituted - Johan Aliouat , Bordeaux Begles',
#      'time': "78'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 40,
#      'text': 'Try - David Strettle , Clermont Auvergne',
#      'time': "77'",
#      'type': 1},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Substitute on - Benjamin Kayser , Clermont Auvergne',
#      'time': "74'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Player substituted - John Ulugia , Clermont Auvergne',
#      'time': "74'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Substitute on - Ludovic Radosavljevic , Clermont Auvergne',
#      'time': "73'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Player substituted - Morgan Parra , Clermont Auvergne',
#      'time': "73'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Player substituted - Ole Avei , Bordeaux Begles',
#      'time': "69'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Substitute on - Benat Auzqui , Bordeaux Begles',
#      'time': "69'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Substitute on - Thomas Domingo , Clermont Auvergne',
#      'time': "69'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Player substituted - Etienne Falgoux , Clermont Auvergne',
#      'time': "69'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Player substituted - Remi Lamerat , Clermont Auvergne',
#      'time': "69'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Substitute on - Aaron Jarvis , Clermont Auvergne',
#      'time': "69'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Substitute on - Benson Stanley , Clermont Auvergne',
#      'time': "69'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Player substituted - Davit Zirakashvili , Clermont Auvergne',
#      'time': "69'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 35,
#      'text': 'Try - Davit Zirakashvili , Clermont Auvergne',
#      'time': "68'",
#      'type': 1},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Yellow card - Louis-Benoit Madaule , Bordeaux Begles',
#      'time': "65'",
#      'type': 5},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Player substituted - Patricio Fernandez , Clermont Auvergne',
#      'time': "64'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Substitute on - Camille Lopez , Clermont Auvergne',
#      'time': "64'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Player substituted - Marc Clerc , Bordeaux Begles',
#      'time': "61'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Substitute on - Jean-Baptiste Poux , Bordeaux Begles',
#      'time': "61'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Substitute on - Flip van der Merwe , Clermont Auvergne',
#      'time': "60'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Player substituted - Paul Jedrasiak , Clermont Auvergne',
#      'time': "60'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Substitute on - Josaia Vakacegu , Bordeaux Begles',
#      'time': "58'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Player substituted - Julien Rey , Bordeaux Begles',
#      'time': "58'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Substitute on - Yann Lesgourgues , Bordeaux Begles',
#      'time': "57'",
#      'type': 8},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Player substituted - Julien Audy , Bordeaux Begles',
#      'time': "57'",
#      'type': 7},
#     {'awayScore': 16,
#      'homeScore': 30,
#      'text': 'Conversion - Morgan Parra , Clermont Auvergne',
#      'time': "57'",
#      'type': 2},
#     {'awayScore': 16,
#      'homeScore': 28,
#      'text': 'Try - David Strettle , Clermont Auvergne',
#      'time': "56'",
#      'type': 1},
#     {'awayScore': 16,
#      'homeScore': 23,
#      'text': 'Conversion - Lionel Beauxis , Bordeaux Begles',
#      'time': "55'",
#      'type': 2},
#     {'awayScore': 14,
#      'homeScore': 23,
#      'text': 'Try - Metuisela Talebula , Bordeaux Begles',
#      'time': "54'",
#      'type': 1},
#     {'awayScore': 9,
#      'homeScore': 23,
#      'text': 'Player substituted - Judicael Cancoriet , Clermont Auvergne',
#      'time': "53'",
#      'type': 7},
#     {'awayScore': 9,
#      'homeScore': 23,
#      'text': 'Substitute on - Damien Chouly , Clermont Auvergne',
#      'time': "53'",
#      'type': 8},
#     {'awayScore': 9,
#      'homeScore': 23,
#      'text': 'Substitute on - John Ulugia , Clermont Auvergne',
#      'time': "53'",
#      'type': 8},
#     {'awayScore': 9,
#      'homeScore': 23,
#      'text': 'Player substituted - Benjamin Kayser , Clermont Auvergne',
#      'time': "53'",
#      'type': 7},
#     {'awayScore': 9,
#      'homeScore': 23,
#      'text': 'Conversion - Morgan Parra , Clermont Auvergne',
#      'time': "52'",
#      'type': 2},
#     {'awayScore': 9,
#      'homeScore': 21,
#      'text': 'Try - Paul Jedrasiak , Clermont Auvergne',
#      'time': "51'",
#      'type': 1},
#     {'awayScore': 9,
#      'homeScore': 16,
#      'text': 'Player substituted - Marco Tauleigne , Bordeaux Begles',
#      'time': "43'",
#      'type': 7},
#     {'awayScore': 9,
#      'homeScore': 16,
#      'text': 'Substitute on - Loann Goujon , Bordeaux Begles',
#      'time': "43'",
#      'type': 8},
#     {'awayScore': 9,
#      'homeScore': 16,
#      'text': 'Start of second half',
#      'time': "40'",
#      'type': 11},
#     {'awayScore': 9,
#      'homeScore': 16,
#      'text': 'End of first half',
#      'time': "41'",
#      'type': 10},
#     {'awayScore': 9,
#      'homeScore': 16,
#      'text': 'Penalty goal - Lionel Beauxis , Bordeaux Begles',
#      'time': "41'",
#      'type': 3},
#     {'awayScore': 6,
#      'homeScore': 16,
#      'text': 'Penalty goal - Lionel Beauxis , Bordeaux Begles',
#      'time': "39'",
#      'type': 3},
#     {'awayScore': 3,
#      'homeScore': 16,
#      'text': 'Penalty goal - Morgan Parra , Clermont Auvergne',
#      'time': "35'",
#      'type': 3},
#     {'awayScore': 3,
#      'homeScore': 13,
#      'text': 'Penalty goal - Lionel Beauxis , Bordeaux Begles',
#      'time': "26'",
#      'type': 3},
#     {'awayScore': 0,
#      'homeScore': 13,
#      'text': 'Player substituted - Loann Goujon , Bordeaux Begles',
#      'time': "23'",
#      'type': 7},
#     {'awayScore': 0,
#      'homeScore': 13,
#      'text': 'Substitute on - Marco Tauleigne , Bordeaux Begles',
#      'time': "23'",
#      'type': 8},
#     {'awayScore': 0,
#      'homeScore': 13,
#      'text': 'Penalty goal - Morgan Parra , Clermont Auvergne',
#      'time': "22'",
#      'type': 3},
#     {'awayScore': 0,
#      'homeScore': 10,
#      'text': 'Substitute on - Loann Goujon , Bordeaux Begles',
#      'time': "18'",
#      'type': 8},
#     {'awayScore': 0,
#      'homeScore': 10,
#      'text': 'Player substituted - Marco Tauleigne , Bordeaux Begles',
#      'time': "18'",
#      'type': 7},
#     {'awayScore': 0,
#      'homeScore': 10,
#      'text': 'Conversion - Morgan Parra , Clermont Auvergne',
#      'time': "16'",
#      'type': 2},
#     {'awayScore': 0,
#      'homeScore': 8,
#      'text': 'Try - Remi Lamerat , Clermont Auvergne',
#      'time': "14'",
#      'type': 1},
#     {'awayScore': 0,
#      'homeScore': 3,
#      'text': 'Penalty goal - Morgan Parra , Clermont Auvergne',
#      'time': "5'",
#      'type': 3},
#     {'awayScore': 0,
#      'homeScore': 0,
#      'text': 'Start of first half',
#      'time': "1'",
#      'type': 9}],
#    'link': {'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/commentary?gameId=290268&league=270559',
#     'isRouterLink': True,
#     'pageType': 'commentary',
#     'text': 'Full Commentary',
#     'to': '/rugby/commentary?gameId=290268&league=270559',
#     'trackingName': '&lpos=rugby:game:subnav:commentary'},
#    'sport': 'rugby',
#    'text': {'allBtn': 'All Commentary',
#     'keyBtn': 'Key Events',
#     'viewAll': 'Match Commentary',
#     'viewKey': 'Key Events'}},
#   'matchConversation': {'href': 'www.espn.co.uk/rugby/conversation?gameId=290268&league=270559',
#    'text': {'description': 'Use a <a href="https://www.facebook.com/r.php" rel="nofollow">Facebook account</a> to add a comment, subject to Facebook\'s <a href="https://www.facebook.com/policies/" rel="nofollow">Terms of Service</a> and <a href="https://www.facebook.com/about/privacy/" rel="nofollow">Privacy Policy</a>. Your Facebook name, photo & other personal information you make public on Facebook will appear with your comment, and may be used on ESPN\'s media platforms. <a href="http://espn.com/espn/story/_/id/8756098/espn-facebook-comments-faq">Learn more</a>.',
#     'heading': 'Conversation'}},
#   'matchDefending': {'away': {'color': '#000099',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#     'name': 'BEG'},
#    'col': [[{'data': {'awayTotal': '8',
#        'awayWon': '4',
#        'homeTotal': '4',
#        'homeWon': '3',
#        'text': 'Scrums Won'},
#       'type': 'dataVisIcons'},
#      {'data': {'awayTotal': '15',
#        'awayWon': '13',
#        'homeTotal': '14',
#        'homeWon': '11',
#        'text': 'Lineouts Won'},
#       'type': 'dataVisIcons'}],
#     [{'data': {'awayTotal': '114',
#        'awayWon': 104,
#        'homeTotal': '79',
#        'homeWon': 70,
#        'text': 'Tackles'},
#       'type': 'dataVisPie'}]],
#    'home': {'color': '#FFCC00',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#     'name': 'CLER'},
#    'split': True,
#    'title': ['Set Pieces', 'Defending']},
#   'matchDetails': {'address': '',
#    'attendance': '0',
#    'capacity': '0',
#    'coverage': '',
#    'date': '7:45 PM, September 17, 2016',
#    'percent': 0,
#    'text': {'attendance': 'Attendance',
#     'capacity': 'Capacity',
#     'coverage': 'Coverage',
#     'heading': 'Game Info',
#     'venue': 'Venue'},
#    'venue': 'Stade Marcel-Michelin'},
#   'matchDiscipline': {'away': {'color': '#000099',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#     'name': 'BEG'},
#    'col': [[{'data': {'awayTotal': '13',
#        'awayWon': '13',
#        'homeTotal': '8',
#        'homeWon': '8',
#        'text': 'Penalties Conceded'},
#       'type': 'dataVisCount'}],
#     [{'data': [{'awayValue': '0', 'homeValue': '0', 'text': 'Red Cards'},
#        {'awayValue': '1', 'homeValue': '0', 'text': 'Yellow Cards'},
#        {'awayValue': '0',
#         'homeValue': '0',
#         'text': 'Total Free Kicks Conceded'}],
#       'type': 'table'}]],
#    'home': {'color': '#FFCC00',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#     'name': 'CLER'},
#    'split': False,
#    'title': 'Discipline'},
#   'matchEvents': {'away': {'color': '#000099',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#     'name': 'BEG'},
#    'col': [[{'data': [{'awayValue': '1', 'homeValue': '5', 'text': 'Tries'},
#        {'awayValue': '1', 'homeValue': '3', 'text': 'Conversion Goals'},
#        {'awayValue': '3', 'homeValue': '3', 'text': 'Penalty Goals'},
#        {'awayValue': '80%',
#         'homeValue': '67%',
#         'text': 'Kick Percent Success'}],
#       'type': 'table'}],
#     [{'data': {'awayText': '274',
#        'homeText': '395',
#        'homeValue': 59,
#        'text': 'Metres Run'},
#       'type': 'dataVis'},
#      {'data': [{'awayValue': '28',
#         'homeValue': '28',
#         'text': 'Kicks From Hand'},
#        {'awayValue': '77', 'homeValue': '129', 'text': 'Passes'},
#        {'awayValue': '77', 'homeValue': '110', 'text': 'Runs'}],
#       'type': 'table'}]],
#    'home': {'color': '#FFCC00',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#     'name': 'CLER'},
#    'split': True,
#    'title': ['Match Events', 'Kick/Pass/Run']},
#   'matchGlossary': {'playerPositons': {},
#    'playerStats': {'cleanbreaks': {'abbr': 'CB', 'desc': 'Clean Breaks'},
#     'conversiongoals': {'abbr': 'CG', 'desc': 'Conversion Goals'},
#     'defendersbeaten': {'abbr': 'DB', 'desc': 'Defenders Beaten'},
#     'dropgoalsconverted': {'abbr': 'DGC', 'desc': 'Drop Goals Converted'},
#     'kicks': {'abbr': 'K', 'desc': 'Kicks'},
#     'lineoutswon': {'abbr': 'LW', 'desc': 'Lineouts Won'},
#     'lineoutwonsteal': {'abbr': 'LWS', 'desc': 'Lineout Won Steal'},
#     'metres': {'abbr': 'MR', 'desc': 'Metres Run'},
#     'missedtackles': {'abbr': 'MT', 'desc': 'Missed Tackles'},
#     'offload': {'abbr': 'O', 'desc': 'Offload'},
#     'passes': {'abbr': 'P', 'desc': 'Passes'},
#     'penaltiesconceded': {'abbr': 'PC', 'desc': 'Penalties Conceded'},
#     'penaltygoals': {'abbr': 'PG', 'desc': 'Penalty Goals'},
#     'points': {'abbr': 'PTS', 'desc': 'Points'},
#     'redcards': {'abbr': 'RC', 'desc': 'Red Cards'},
#     'runs': {'abbr': 'R', 'desc': 'Runs'},
#     'tackles': {'abbr': 'T', 'desc': 'Tackles'},
#     'tries': {'abbr': 'T', 'desc': 'Tries'},
#     'tryassists': {'abbr': 'TA', 'desc': 'Try Assists'},
#     'turnoversconceded': {'abbr': 'TC', 'desc': 'Turnovers Conceded'},
#     'yellowcards': {'abbr': 'YC', 'desc': 'Yellow Cards'}},
#    'teamStats': {'cleanbreaks': {'abbr': 'CB', 'desc': 'Clean Breaks'},
#     'conversiongoals': {'abbr': 'CG', 'desc': 'Conversion Goals'},
#     'defendersbeaten': {'abbr': 'DB', 'desc': 'Defenders Beaten'},
#     'kickpercentsuccess': {'abbr': 'KPS', 'desc': 'Kick Percent Success'},
#     'kicksfromhand': {'abbr': 'KFH', 'desc': 'Kicks From Hand'},
#     'lineoutswon': {'abbr': 'LW', 'desc': 'Lineouts Won'},
#     'maulstotal': {'abbr': 'MT', 'desc': 'Mauls Total'},
#     'maulswon': {'abbr': 'MW', 'desc': 'Mauls Won'},
#     'metres': {'abbr': 'MR', 'desc': 'Metres Run'},
#     'missedtackles': {'abbr': 'MT', 'desc': 'Missed Tackles'},
#     'offload': {'abbr': 'O', 'desc': 'Offload'},
#     'passes': {'abbr': 'P', 'desc': 'Passes'},
#     'pcpossessionfirst': {'abbr': 'PPF', 'desc': 'Pc Possession First'},
#     'pcpossessionsecond': {'abbr': 'PPS', 'desc': 'Pc Possession Second'},
#     'pcterritoryfirst': {'abbr': 'PTF', 'desc': 'Pc Territory First'},
#     'pcterritorysecond': {'abbr': 'PTS', 'desc': 'Pc Territory Second'},
#     'penaltiesconceded': {'abbr': 'PC', 'desc': 'Penalties Conceded'},
#     'penaltygoals': {'abbr': 'PG', 'desc': 'Penalty Goals'},
#     'possession': {'abbr': 'P', 'desc': 'Possession'},
#     'redcards': {'abbr': 'RC', 'desc': 'Red Cards'},
#     'ruckstotal': {'abbr': 'RT', 'desc': 'Rucks Total'},
#     'ruckswon': {'abbr': 'RW', 'desc': 'Rucks Won'},
#     'runs': {'abbr': 'R', 'desc': 'Runs'},
#     'scrumstotal': {'abbr': 'ST', 'desc': 'Scrums Total'},
#     'scrumswon': {'abbr': 'SW', 'desc': 'Scrums Won'},
#     'tackles': {'abbr': 'T', 'desc': 'Tackles'},
#     'territory': {'abbr': 'T', 'desc': 'Territory'},
#     'totalfreekicksconceded': {'abbr': 'TFKC',
#      'desc': 'Total Free Kicks Conceded'},
#     'totallineouts': {'abbr': 'TL', 'desc': 'Total Lineouts'},
#     'tries': {'abbr': 'T', 'desc': 'Tries'},
#     'turnoverknockon': {'abbr': 'TKO', 'desc': 'Turnover Knock On'},
#     'turnoversconceded': {'abbr': 'TC', 'desc': 'Turnovers Conceded'},
#     'yellowcards': {'abbr': 'YC', 'desc': 'Yellow Cards'}}},
#   'matchHomeForm': {'data': [{'away': {'abbreviation': 'MONTP',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25918/montpellier-herault',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25918/montpellier-herault',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/default-team-logo-500.png&h=35&w=35',
#       'name': 'MONTP'},
#      'date': '2017-03-12T16:00Z',
#      'home': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=290372&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=290372&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'L',
#      'resultValue': 'L',
#      'score': '19-28'},
#     {'away': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'date': '2017-03-04T13:45Z',
#      'home': {'abbreviation': 'CAS',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25916/castres-olympique',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25916/castres-olympique',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25916.png&h=35&w=35',
#       'name': 'CAS'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=290365&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=290365&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'L',
#      'resultValue': 'L',
#      'score': '26-16'},
#     {'away': {'abbreviation': 'BAY',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25912/bayonne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25912/bayonne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a.espncdn.com/combiner/i?img=/i/teamlogos/soccer/500/default-team-logo-500.png&h=35&w=35',
#       'name': 'BAY'},
#      'date': '2017-02-18T17:30Z',
#      'home': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
#       'href': '/rugby/match?gameId=290361&league=270559',
#       'isRouterLink': True,
#       'text': '',
#       'to': '/rugby/match?gameId=290361&league=270559',
#       'trackingName': '&lpos=rugby:game:subnav:history'},
#      'result': 'W',
#      'resultValue': 'W',
#      'score': '46-27'},
#     {'away': {'abbreviation': 'CLER',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/25917/clermont-auvergne',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#       'name': 'CLER'},
#      'date': '2017-01-29T15:45Z',
#      'home': {'abbreviation': 'BEG',
#       'link': {'classes': [],
#        'dataRoute': False,
#        'external': False,
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'isRouterLink': True,
#        'text': '',
#        'to': '/rugby/team/_/id/143737/bordeaux-begles',
#        'trackingName': '&lpos=rugby:game:subnav:history'},
#       'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#       'name': 'BEG'},
#      'league': 'Top 14 Orange',
#      'link': {'classes': [],
#       'dataRoute': False,
#       'external': False,
# ...
#       'passes': {'name': 'Passes', 'value': '2'},
#       'penalties': {'name': 'penalties', 'value': '0'},
#       'penaltiesconceded': {'name': 'Penalties Conceded', 'value': '0'},
#       'penaltygoals': {'name': 'Penalty Goals', 'value': '0'},
#       'points': {'name': 'Points', 'value': '0'},
#       'position': 'F',
#       'redcards': {'name': 'Red Cards', 'value': '0'},
#       'runs': {'name': 'Runs', 'value': '4'},
#       'subToolTip': '',
#       'subbed': False,
#       'tackles': {'name': 'Tackles', 'value': '8'},
#       'tries': {'name': 'Tries', 'value': '0'},
#       'tryassists': {'name': 'Try Assists', 'value': '0'},
#       'turnoversconceded': {'name': 'Turnovers Conceded', 'value': '0'},
#       'url': 'http://en.espn.co.uk/sport/rugby/player/27491.html',
#       'wasActive': True,
#       'yellowcards': {'name': 'Yellow Cards', 'value': '0'}},
#      {'captain': False,
#       'cleanbreaks': {'name': 'Clean Breaks', 'value': '1'},
#       'conversiongoals': {'name': 'Conversion Goals', 'value': '0'},
#       'defendersbeaten': {'name': 'Defenders Beaten', 'value': '1'},
#       'dropgoalsconverted': {'name': 'Drop Goals Converted', 'value': '0'},
#       'eventTimes': {},
#       'homeAway': 'home',
#       'id': '120471',
#       'kicks': {'name': 'Kicks', 'value': '0'},
#       'lineoutswon': {'name': 'Lineouts Won', 'value': '0'},
#       'lineoutwonsteal': {'name': 'Lineout Won Steal', 'value': '0'},
#       'metres': {'name': 'Metres Run', 'value': '51'},
#       'missedtackles': {'name': 'Missed Tackles', 'value': '0'},
#       'name': 'Fritz Lee',
#       'number': '8',
#       'offload': {'name': 'Offload', 'value': '1'},
#       'onPitch': True,
#       'passes': {'name': 'Passes', 'value': '8'},
#       'penalties': {'name': 'penalties', 'value': '0'},
#       'penaltiesconceded': {'name': 'Penalties Conceded', 'value': '1'},
#       'penaltygoals': {'name': 'Penalty Goals', 'value': '0'},
#       'points': {'name': 'Points', 'value': '0'},
#       'position': 'N8',
#       'redcards': {'name': 'Red Cards', 'value': '0'},
#       'runs': {'name': 'Runs', 'value': '15'},
#       'subToolTip': '',
#       'subbed': False,
#       'tackles': {'name': 'Tackles', 'value': '11'},
#       'tries': {'name': 'Tries', 'value': '0'},
#       'tryassists': {'name': 'Try Assists', 'value': '0'},
#       'turnoversconceded': {'name': 'Turnovers Conceded', 'value': '1'},
#       'url': 'http://en.espn.co.uk/sport/rugby/player/120471.html',
#       'wasActive': True,
#       'yellowcards': {'name': 'Yellow Cards', 'value': '0'}}]},
#    'show': True,
#    'sport': 'rugby',
#    'text': {'attacking': 'Attacking',
#     'col2': 'NO.',
#     'col3': 'NAME',
#     'defending': 'Defending',
#     'discipline': 'Discipline',
#     'note': '*Players currently on the pitch are shown in bold',
#     'scoring': 'Scoring',
#     'split': 'Replacements'}},
#   'matchStats': {'away': {'color': '#000099',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/143737.png&h=35&w=35',
#     'name': 'BEG'},
#    'dataVis': [{'awayText': '17%',
#      'awayValue': 17,
#      'homeText': '82%',
#      'homeValue': 82,
#      'text': 'Possession'},
#     {'awayText': '0%',
#      'awayValue': 0,
#      'homeText': '0%',
#      'homeValue': 0,
#      'text': 'Territory'}],
#    'home': {'color': '#FFCC00',
#     'logo': 'http://a1.espncdn.com/combiner/i?img=/i/teamlogos/rugby/teams/500/25917.png&h=35&w=35',
#     'name': 'CLER'},
#    'isTeamLinkActive': True,
#    'link': {'classes': [],
#     'dataRoute': False,
#     'external': False,
#     'href': '/rugby/matchstats?gameId=290268&league=270559',
#     'isRouterLink': True,
#     'pageType': 'matchstats',
#     'text': 'Full Match Stats',
#     'to': '/rugby/matchstats?gameId=290268&league=270559',
#     'trackingName': '&lpos=rugby:game:subnav:matchstats'},
#    'sport': 'rugby',
#    'table': [{'awayValue': '77', 'homeValue': '110', 'text': 'Runs'},
#     {'awayValue': '274', 'homeValue': '395', 'text': 'Metres Run'},
#     {'awayValue': '2', 'homeValue': '3', 'text': 'Clean Breaks'},
#     {'awayValue': '114', 'homeValue': '79', 'text': 'Tackles'},
#     {'awayValue': '10', 'homeValue': '9', 'text': 'Missed Tackles'},
#     {'awayValue': '12', 'homeValue': '11', 'text': 'Turnover Knock On'}],
#    'title': 'Match Stats'},
#   'matchSummary': {'away': {'conversiongoals': [{'link': 'http://en.espn.co.uk/sport/rugby/player/15437.html',
#       'name': 'Lionel Beauxis',
#       'rawClock': 0,
#       'times': ["55'"]}],
#     'penalties': [{'link': 'http://en.espn.co.uk/sport/rugby/player/15437.html',
#       'name': 'Lionel Beauxis',
#       'rawClock': 0,
#       'times': ["26'", "39'", "41'"]}],
#     'tries': [{'link': 'http://en.espn.co.uk/sport/rugby/player/165812.html',
#       'name': 'Metuisela Talebula',
#       'rawClock': 0,
#       'times': ["54'"]}]},
#    'home': {'conversiongoals': [{'link': 'http://en.espn.co.uk/sport/rugby/player/15818.html',
#       'name': 'Morgan Parra',
#       'rawClock': 0,
#       'times': ["16'", "52'", "57'"]}],
#     'penalties': [{'link': 'http://en.espn.co.uk/sport/rugby/player/15818.html',
#       'name': 'Morgan Parra',
#       'rawClock': 0,
#       'times': ["5'", "22'", "35'"]}],
#     'tries': [{'link': 'http://en.espn.co.uk/sport/rugby/player/206491.html',
#       'name': 'Remi Lamerat',
#       'rawClock': 0,
#       'times': ["14'"]},
#      {'link': 'http://en.espn.co.uk/sport/rugby/player/158874.html',
#       'name': 'Paul Jedrasiak',
#       'rawClock': 0,
#       'times': ["51'"]},
#      {'link': 'http://en.espn.co.uk/sport/rugby/player/15468.html',
#       'name': 'David Strettle',
#       'rawClock': 0,
#       'times': ["56'", "77'"]},
#      {'link': 'http://en.espn.co.uk/sport/rugby/player/14620.html',
#       'name': 'Davit Zirakashvili',
#       'rawClock': 0,
#       'times': ["68'"]}]}},
#   'meta': {'canonical': '/rugby/playerstats?gameId=290268&league=270559',
#    'competitionUID': 's:300~l:8005~e:290268~c:290268',
#    'description': 'Get the player statistics of the Clermont Auvergne vs Bordeaux Begles Top 14 Orange 2017 rugby match.',
#    'gameId': '290268',
#    'gameState': 'post',
#    'image': 'http://a1.espncdn.com/combiner/i?img=%2Fi%2Fespn%2Fespn_logos%2Fespn_red.png',
#    'keywords': 'Clermont Auvergne vs Bordeaux Begles, player statistics, Top 14 Orange 2017, rugby',
#    'leagueId': '',
#    'leagueName': '',
#    'matchDescription': '',
#    'shortTitle': 'CLER vs BEG',
#    'sport': 'rugby',
#    'title': 'Clermont Auvergne vs Bordeaux Begles - Player Statistics - Top 14 Orange 2017 - 17 Sep, 2016 - ESPN',
#    'website': 'article'},
#   'news': {'items': [{'description': '125 years on since Stade Francais played Racing in the first ever French Championship final the two sides have announced a remarkable merger. Martin Gillingham tries to make sense of it all.',
#      'headline': "Breaking down a bombshell: Racing 92's merger with Stade Francais",
#      'href': '/rugby/story/_/id/18898191/breaking-bombshell-racing-92-merger-stade-francais-top-14-rugby',
#      'image': {'url': 'http://a1.espncdn.com/combiner/i?img=/photo/2017/0313/r189876_608x342_16-9.jpg'}},
#     {'description': "The Racing 92 - Stade Francais proposed merger has raised more questions than answers. ESPN takes a look at what the team's squad could look like based on the current crop of players in Paris.",
#      'headline': 'Merged XV: The best combined side from Racing 92 and Stade Francais',
#      'href': '/rugby/story/_/id/18896947/racing-92-stade-francais-merger-best-team-current-squads',
#      'image': {'url': 'http://a1.espncdn.com/combiner/i?img=/photo/2017/0313/r189841_608x342_16-9.jpg'}},
#     {'description': 'Top 14 giants Racing 92 and Stade Francais have announced they are to merge to form one Paris super club.',
#      'headline': 'Racing 92 and Stade Francais to merge to form Paris super club',
#      'href': '/rugby/story/_/id/18896501/racing-92-stade-francais-merge-form-paris-super-club',
#      'image': {'url': 'http://a1.espncdn.com/combiner/i?img=/photo/2016/1008/r137567_608x342_16-9.jpg'}},
#     {'description': 'All Blacks great Dan Carter has been booed off the field in his first French rugby match since being caught drink-driving in Paris.',
#      'headline': 'Former All Black Dan Carter booed in Racing 92 return following drink-driving charge',
#      'href': '/rugby/story/_/id/18892611/former-all-black-dan-carter-booed-racing-92-return-following-drink-driving-charge',
#      'image': {'url': 'http://a1.espncdn.com/combiner/i?img=/photo/2016/1006/r137079_1296x518_5-2.jpg'}},
#     {'description': "Toulon's playoff ambitions suffered a setback as Brive defeated Toulon 15-5 on Saturday evening .",
#      'headline': 'TOP 14 Wrap - Toulon, Clermont defeated, La Rochelle go top',
#      'href': '/rugby/story/_/id/18824211/top-14-wrap-toulon-clermont-fall-defeat-la-rochelle-go-top',
#      'image': {'url': 'http://a1.espncdn.com/combiner/i?img=/photo/2017/0305/r187411_608x342_16-9.jpg'}},
#     {'description': 'France have retained 19 players ahead of their round four match against Italy with the rest of the squad released for Top 14 duties.',
#      'headline': 'France team takes shape ahead of round four Six Nations match against Italy',
#      'href': '/rugby/story/_/id/18795217/france-team-takes-shape-ahead-round-four-six-nations-match-italy',
#      'image': {'url': 'http://a1.espncdn.com/combiner/i?img=/photo/2016/1112/r151230_608x342_16-9.jpg'}}],
#    'title': 'Top 14 Orange 2017 News'},
#   'polling': {'duration': 45000, 'enabled': False},
#   'showGameDetailFooter': True,
#   'standings': {'isTeamLinkActive': True,
#    'link': {'external': False,
#     'href': '/rugby/table/_/league/270559',
#     'title': 'Full Table'},
#    'teams': [{'abbreviation': 'Top 14 Orange',
#      'keys': [{'text': 'R', 'tooltip': 'Rank', 'type': 'rank'},
#       {'text': 'TEAM', 'tooltip': 'Team', 'type': 'team'},
#       {'text': 'GP', 'tooltip': 'Games Played', 'type': 'gamesplayed'},
#       {'text': 'PD',
#        'tooltip': 'Points Difference',
#        'type': 'pointsdifference'},
#       {'text': 'P', 'tooltip': 'Points', 'type': 'points'}],
#      'teams': [{'abbrev': 'LA RO',
#        'displayName': 'La Rochelle',
#        'href': '/rugby/team/_/id/119318/la-rochelle',
#        'id': '119318',
#        'stats': ['1', '', '20', '+174', '66'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'CLER',
#        'displayName': 'Clermont Auvergne',
#        'href': '/rugby/team/_/id/25917/clermont-auvergne',
#        'id': '25917',
#        'stats': ['2', '', '20', '+146', '58'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'MONTP',
#        'displayName': 'Montpellier Herault',
#        'href': '/rugby/team/_/id/25918/montpellier-herault',
#        'id': '25918',
#        'stats': ['3', '', '20', '+61', '55'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'PAU',
#        'displayName': 'Pau',
#        'href': '/rugby/team/_/id/270567/pau',
#        'id': '270567',
#        'stats': ['4', '', '20', '+17', '52'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'CAS',
#        'displayName': 'Castres Olympique',
#        'href': '/rugby/team/_/id/25916/castres-olympique',
#        'id': '25916',
#        'stats': ['5', '', '20', '+107', '51'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'TOUL',
#        'displayName': 'Toulon',
#        'href': '/rugby/team/_/id/25986/toulon',
#        'id': '25986',
#        'stats': ['6', '', '20', '+117', '51'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'RAMET',
#        'displayName': 'Racing 92',
#        'href': '/rugby/team/_/id/99855/racing-92',
#        'id': '99855',
#        'stats': ['7', '', '20', '+16', '45'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'BEG',
#        'displayName': 'Bordeaux Begles',
#        'href': '/rugby/team/_/id/143737/bordeaux-begles',
#        'id': '143737',
#        'stats': ['8', '', '20', '+6', '44'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'BRIV',
#        'displayName': 'Brive',
#        'href': '/rugby/team/_/id/25915/brive',
#        'id': '25915',
#        'stats': ['9', '', '20', '-44', '44'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'TOUL',
#        'displayName': 'Stade Toulousain',
#        'href': '/rugby/team/_/id/25922/stade-toulousain',
#        'id': '25922',
#        'stats': ['10', '', '20', '-2', '43'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'LYON',
#        'displayName': 'Lyon',
#        'href': '/rugby/team/_/id/143736/lyon',
#        'id': '143736',
#        'stats': ['11', '', '20', '-58', '41'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'SFRAN',
#        'displayName': 'Stade Francais Paris',
#        'href': '/rugby/team/_/id/25921/stade-francais-paris',
#        'id': '25921',
#        'stats': ['12', '', '20', '-32', '40'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'GRENO',
#        'displayName': 'Grenoble',
#        'href': '/rugby/team/_/id/167303/grenoble',
#        'id': '167303',
#        'stats': ['13', '', '20', '-185', '27'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'},
#       {'abbrev': 'BAY',
#        'displayName': 'Bayonne',
#        'href': '/rugby/team/_/id/25912/bayonne',
#        'id': '25912',
#        'stats': ['14', '', '20', '-323', '22'],
#        'trackingName': '&lpos=rugby:gamepackage:Standings:Team'}]}],
#    'title': 'Standings',
#    'uid': 's:300~l:8005'}},
#  'leagues': {},
#  'news': {},
#  'page': {'appProps': {'device': {'desktop': True}},
#   'edition': {'country': 'gb',
#    'domain': 'www.espn.co.uk',
#    'editionKey': 'espnuk-en',
#    'host': 'espn.co.uk',
#    'https': False,
#    'language': 'en',
#    'outbrain': {'desktop': {'compliantId': 'AR_3', 'nonCompliantId': 'AR_4'},
#     'enabled': True,
#     'mobile': {'compliantId': 'MB_3', 'nonCompliantId': 'MB_4'},
#     'template': 'espnuk',
#     'video': {'desktop': {'compliantId': 'AR_16'},
#      'mobile': {'compliantId': 'MB_6'}}},
#    'reactOverride': {'cricket': {'scores': True}},
#    'site': 'espnuk',
#    'timeZoneBucket': 'Europe/London',
#    'timeZoneDomain': 'Europe/London',
#    'translations': {'dropdown.leagues.default.cricket': 'All Series',
#     'dropdown.leagues.default.rugby': 'All Leagues',
#     'dropdown.leagues.default.sport': 'All Leagues',
#     'facebook.conversation.account_policy': 'Use a <a href="https://www.facebook.com/r.php" rel="nofollow">Facebook account</a> to add a comment, subject to Facebook\'s <a href="https://www.facebook.com/policies/" rel="nofollow">Terms of Service</a> and <a href="https://www.facebook.com/about/privacy/" rel="nofollow">Privacy Policy</a>. Your Facebook name, photo & other personal information you make public on Facebook will appear with your comment, and may be used on ESPN\'s media platforms. <a href="http://espn.com/espn/story/_/id/8756098/espn-facebook-comments-faq">Learn more</a>.',
#     'links.event.commentary.metadata.text.rugby': 'Commentary',
#     'links.event.conversation.metadata.text.rugby': 'Conversation',
#     'links.event.lineups.metadata.text.rugby': 'Lineups',
#     'links.event.live.metadata.text.rugby': 'Gamecast',
#     'links.event.matchstats.metadata.text.rugby': 'Match Stats',
#     'links.event.playerstats.metadata.text.rugby': 'Player Stats',
#     'links.event.preview.metadata.text.rugby': 'Preview',
#     'links.event.recap.metadata.text.rugby': 'Report',
#     'links.event.summary.metadata.text.rugby': 'Summary',
#     'links.event.table.metadata.text.rugby': 'Table'}},
#   'params': {'gameId': '290268',
#    'league': '270559',
#    'pageType': 'playerstats',
#    'root': 'rugby',
#    'slug': '',
#    'sport': 'rugby'},
#   'template': 'gamepackage'},
#  'routing': {'location': {'$searchBase': {'search': '', 'searchBase': ''},
#    'action': 'POP',
#    'hash': '',
#    'key': '4iadqf',
#    'pathname': '/',
#    'query': {},
#    'search': '',
#    'state': None}},
#  'schedule': {},
#  'scoreboard': {},
#  'standings': {},
#  'utils': {}}

# %%
def getPlayerVals(d):

    dct = d
    dct['match_date'] = date
    dct['match_id'] = match_id[0] # regex above returns list of one element
    if 'id' in dct:
        dct['player_id'] = dct.pop('id') # rename 'id' to 'player_id'
    # This value should be unique and will be the primary key of the table
    dct['row_nk'] = dct['player_id'] + dct['match_id'] 

    # remove entries we don't want - url is useless and eventTimes doesn't conform to the required structure
    # these are the keys, i.e. table column names
    cols = list(dct.keys())
    cols = list(filter(lambda c: c != 'eventTimes', cols))
    cols = list(filter(lambda c: c != 'url', cols))

    # these are used for the SQL query, so everything gets inserted at once
    placeholders = ', '.join(['%s'] * len(cols))
    columns = ', '.join(cols)

    # These are the values to be inserted into the table. Sometimes the values is a single value
    # and other times is a dictionary, handle both instances
    vals = []
    for d in dct:
        if d in cols:
            if type(dct[d]) is dict:
                vals.append(dct[d]['value'])
            else:
                vals.append(dct[d])

    return placeholders, columns, vals

# %%
# query to create the table in MySQL - this will need a match and player identifier
sql = """drop table if exists scraping.p_stats;
        create table p_stats( row_nk varchar(50) not null
                            , player_id bigint(7) not null
                            , match_id varchar(20) not null
                            , match_date varchar(20)
                            , name varchar(200)
                            , number varchar(10)
                            , position varchar(10)
                            , captain varchar(10)
                            , subbed varchar(10)
                            , homeAway varchar(10)
                            , subToolTip varchar(10)
                            , onPitch varchar(10)
                            , wasActive varchar(10)
                            , tries bigint(7)
                            , tryassists bigint(7)
                            , points bigint(7)
                            , kicks bigint(7)
                            , passes bigint(7)
                            , runs bigint(7)
                            , metres bigint(7)
                            , cleanbreaks bigint(7)
                            , defendersbeaten bigint(7)
                            , offload bigint(7)
                            , lineoutwonsteal bigint(7)
                            , turnoversconceded bigint(7)
                            , tackles bigint(7)
                            , missedtackles bigint(7)
                            , lineoutswon bigint(7)
                            , penaltiesconceded bigint(7)
                            , yellowcards bigint(7)
                            , redcards bigint(7)
                            , penalties bigint(7)
                            , penaltygoals bigint(7)
                            , conversiongoals bigint(7)
                            , dropgoalsconverted bigint(7)
                            , primary key(row_nk));""".replace("\n", "")

# Run this first to set up connection drop the table, and create again before putting more data into it

# Set up the connection
import pymysql
conn = pymysql.connect(host = '127.0.0.1', port = 3306,
                       user = 'root', passwd = '', db = 'mysql')

cur = conn.cursor()
cur.execute("USE scraping")
cur.execute(sql)
# Out:
# 0

# %%
dt = pd.date_range('20160801','20170317')
#dt = pd.date_range('20160801','20160831')
dates = dt.format(formatter=lambda x: x.strftime('%Y%m%d'))
dates
# Out:
# ['20160801',
#  '20160802',
#  '20160803',
#  '20160804',
#  '20160805',
#  '20160806',
#  '20160807',
#  '20160808',
#  '20160809',
#  '20160810',
#  '20160811',
#  '20160812',
#  '20160813',
#  '20160814',
#  '20160815',
#  '20160816',
#  '20160817',
#  '20160818',
#  '20160819',
#  '20160820',
#  '20160821',
#  '20160822',
#  '20160823',
#  '20160824',
#  '20160825',
#  '20160826',
#  '20160827',
#  '20160828',
#  '20160829',
#  '20160830',
#  '20160831',
#  '20160901',
#  '20160902',
#  '20160903',
#  '20160904',
#  '20160905',
#  '20160906',
#  '20160907',
#  '20160908',
#  '20160909',
#  '20160910',
#  '20160911',
#  '20160912',
#  '20160913',
#  '20160914',
#  '20160915',
#  '20160916',
#  '20160917',
#  '20160918',
#  '20160919',
#  '20160920',
#  '20160921',
#  '20160922',
#  '20160923',
#  '20160924',
#  '20160925',
#  '20160926',
#  '20160927',
#  '20160928',
#  '20160929',
#  '20160930',
#  '20161001',
#  '20161002',
#  '20161003',
#  '20161004',
#  '20161005',
#  '20161006',
#  '20161007',
#  '20161008',
#  '20161009',
#  '20161010',
#  '20161011',
#  '20161012',
#  '20161013',
#  '20161014',
#  '20161015',
#  '20161016',
#  '20161017',
#  '20161018',
#  '20161019',
#  '20161020',
#  '20161021',
#  '20161022',
#  '20161023',
#  '20161024',
#  '20161025',
#  '20161026',
#  '20161027',
#  '20161028',
#  '20161029',
#  '20161030',
#  '20161031',
#  '20161101',
#  '20161102',
#  '20161103',
#  '20161104',
#  '20161105',
#  '20161106',
#  '20161107',
#  '20161108',
#  '20161109',
#  '20161110',
#  '20161111',
#  '20161112',
#  '20161113',
#  '20161114',
#  '20161115',
#  '20161116',
#  '20161117',
#  '20161118',
#  '20161119',
#  '20161120',
#  '20161121',
#  '20161122',
#  '20161123',
#  '20161124',
#  '20161125',
#  '20161126',
#  '20161127',
#  '20161128',
#  '20161129',
#  '20161130',
#  '20161201',
#  '20161202',
#  '20161203',
#  '20161204',
#  '20161205',
#  '20161206',
#  '20161207',
#  '20161208',
#  '20161209',
#  '20161210',
#  '20161211',
#  '20161212',
#  '20161213',
#  '20161214',
#  '20161215',
#  '20161216',
#  '20161217',
#  '20161218',
#  '20161219',
#  '20161220',
#  '20161221',
#  '20161222',
#  '20161223',
#  '20161224',
#  '20161225',
#  '20161226',
#  '20161227',
#  '20161228',
#  '20161229',
#  '20161230',
#  '20161231',
#  '20170101',
#  '20170102',
#  '20170103',
#  '20170104',
#  '20170105',
#  '20170106',
#  '20170107',
#  '20170108',
#  '20170109',
#  '20170110',
#  '20170111',
#  '20170112',
#  '20170113',
#  '20170114',
#  '20170115',
#  '20170116',
#  '20170117',
#  '20170118',
#  '20170119',
#  '20170120',
#  '20170121',
#  '20170122',
#  '20170123',
#  '20170124',
#  '20170125',
#  '20170126',
#  '20170127',
#  '20170128',
#  '20170129',
#  '20170130',
#  '20170131',
#  '20170201',
#  '20170202',
#  '20170203',
#  '20170204',
#  '20170205',
#  '20170206',
#  '20170207',
#  '20170208',
#  '20170209',
#  '20170210',
#  '20170211',
#  '20170212',
#  '20170213',
#  '20170214',
#  '20170215',
#  '20170216',
#  '20170217',
#  '20170218',
#  '20170219',
#  '20170220',
#  '20170221',
#  '20170222',
#  '20170223',
#  '20170224',
#  '20170225',
#  '20170226',
#  '20170227',
#  '20170228',
#  '20170301',
#  '20170302',
#  '20170303',
#  '20170304',
#  '20170305',
#  '20170306',
#  '20170307',
#  '20170308',
#  '20170309',
#  '20170310',
#  '20170311',
#  '20170312',
#  '20170313',
#  '20170314',
#  '20170315',
#  '20170316',
#  '20170317']

# %%
teams, players = ['home', 'away'], ['team', 'reserves']
#dates = ['20170304', '20170305'] # Testing with two dates
dates = ['20160917']

for date in dates:
    print(date)
    matches = getMatchLinks(date)
    
    if len(matches) > 0:
        for match_link in matches:
            if match_link != '#':
                ma, pl = getStatsLinks(match_link)

                regex = re.compile('gameId=([0-9]*)')
                match_id = regex.findall(match_link)

                if pl != None:
                    p_stats = getStats(pl)

                    for t in teams:
                        for p in players:
                            data = p_stats["gamePackage"]["matchLineUp"][t][p]
                            for d in data:               
                                placeholders, columns, vals = getPlayerVals(d)

                                cur = conn.cursor()
                                cur.execute("USE scraping")

                                # Execute the SQL to update the table
                                sql_update = "insert into p_stats (%s) values (%s)" % (columns, placeholders)
                                cur.execute(sql_update, vals)
                                conn.commit()

cur.close()
conn.close()
# Out:
# 20160917

# %%
# Run this if the code fails to close the DB connection
cur.close()
conn.close()
